# %% [markdown]
# <h1 style="color: darkblue; text-align: center; font-family: Arial, sans-serif; font-size: 32px;">
#   Logistic Regression
# </h1>

# %%
# EXP NO: 8

# %%
#Aim: To build a model that predicts the probability of a binary outcome by fitting data to a logistic function.

# %%
#Name: Rutik v. giri
#Roll no: 17
#sec: A
#subject: EMERGING TECH. LAB - I

# %%
import pandas as pd 
import numpy as np
import os
os.getcwd()
# Out:
# 'C:\\Users\\rutik'

# %%
os.chdir(r'C:\Users\rutik\OneDrive\Desktop')

# %%
data=pd.read_csv("heart.csv")

# %%
x=data.drop("target", axis=1)
y=data["target"]

# %%
#splitting the data into training and testing data sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()
log.fit(x_train, y_train)
# Out:
# C:\Users\rutik\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score (y_test,y_pred)
# Out:
# 0.7853658536585366

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
labels = np.unique(y_test)  # Get unique class labels
cm = pd.DataFrame(cm, index=labels, columns=labels)

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', linewidths=1, linecolor='black')  

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Select two features and target
X_vis = x_train[['age', 'chol']]
y_vis = y_train

# Train Logistic Regression
model = LogisticRegression()
model.fit(X_vis, y_vis)

# Create grid
xx, yy = np.meshgrid(np.linspace(X_vis['age'].min()-1, X_vis['age'].max()+1, 500),
                     np.linspace(X_vis['chol'].min()-1, X_vis['chol'].max()+1, 500))

# Predict probabilities for each point in grid
Z = model.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
Z = Z.reshape(xx.shape)

plt.figure(figsize=(8,6))

# Plot decision boundary (probability=0.5 contour)
plt.contour(xx, yy, Z, levels=[0.5], colors='k', linewidths=2)

# Plot data points
plt.scatter(X_vis['age'], X_vis['chol'], c=y_vis, cmap='coolwarm', edgecolor='k', s=70)

plt.title("Logistic Regression Decision Boundary: Age vs Cholesterol")
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.grid(True)
plt.show()
# Out:
# C:\Users\rutik\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### ✅ Conclusion:
# The logistic regression model effectively estimates the probability of a binary outcome by fitting the data to a logistic function, enabling accurate classification and prediction.
