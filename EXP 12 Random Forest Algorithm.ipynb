# %% [markdown]
# <h1 style="color: darkblue; text-align: center; font-family: Arial, sans-serif; font-size: 32px;">
#  Random Forest Algorithm
# </h1>

# %%
#EXP NO: 12

# %%
#Aim: To build an accurate and reliable model using the Random Forest algorithm.

# %%
#Name: Rutik v. giri
#Roll no: 17
#sec: A
#subject: EMERGING TECH. LAB - I

# %%
import pandas as pd 
import numpy as np
import os
os.getcwd()
# Out:
# 'C:\\Users\\rutik\\OneDrive\\Desktop'

# %%
os.chdir(r'C:\Users\rutik\OneDrive\Desktop')

# %%
data = pd.read_csv("heart.csv")

# %%
x=data.drop("target", axis=1)
y=data["target"]

# %%
#splitting the data into training and testing data sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
rf=RandomForestClassifier()

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)

# %%
accuracy_score (y_test,y_pred)
# Out:
# 0.9853658536585366

# %%
import matplotlib.pyplot as plt

data['target'].value_counts().plot(kind='bar', color=['salmon', 'skyblue'])
plt.title('Distribution of Target Variable')
plt.xlabel('Target Class')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

importances = rf.feature_importances_
features = x_train.columns  # assuming x_train is a DataFrame

plt.figure(figsize=(10, 6))
pd.Series(importances, index=features).sort_values().plot(kind='barh', color='Orange')
plt.title('Feature Importance from Random Forest')
plt.xlabel('Importance Score')
plt.show()

# %% [markdown]
# ### ✅ Conclusion:
# The Random Forest algorithm builds an accurate and reliable model by aggregating multiple decision trees, improving prediction performance and reducing overfitting.
